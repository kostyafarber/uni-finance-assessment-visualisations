# %% [markdown]
# # Visualisations for my Finance Assignment
# ***
# Below are some visualisations I made for one of my university finance assignments for a portfolio and investment mangagment class.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-pastel')
# %matplotlib inline

# %%
# Data to plot
labels = 'Domestic Equities', 'International Equities', 'Global Fixed Income', 'Alternatives', 'Cash'
sizes_r1 = [0.2, 0.173, 0.159, 0.418, 0.050]
explode_1 = (0, 0, 0, 0.1, 0)  # explode 1st slice
colors_1 = ['darkkhaki','gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

labels_2 ='Domestic Equities','International \n\n Equities', 'Global Fixed Income', 'Alternatives', 'Cash'
sizes_r2 = [0, 0.264, 0.288, 0.398, 0.050]
explode_2 = (0, 0, 0, 0.1, 0)  # explode 1st slice
colors_2 = ['darkkhaki','gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

fig, (ax1,ax2) = plt.subplots(1, 2,figsize=(10,5))

ax1.pie(sizes_r1, explode=explode_1, labels=labels, colors=colors_1,
        autopct='%1.1f%%', shadow=True, startangle=140)

ax2.pie(sizes_r2, explode=explode_2, labels=labels_2, colors=colors_2, 
        autopct='%1.1f%%', shadow=True, startangle=140)

ax1.axis('equal')
plt.show()
#fig.savefig('Q1Piechart.eps',format='eps', dpi=1000)

# %%
# Data to plot
labels = 'Domestic Equities', 'International Equities', 'Global Fixed Income', 'Alternatives', 'Cash'
sizes_r1 = [0.2, 0.173, 0.159, 0.418, 0.050]
explode_1 = (0, 0, 0, 0.1, 0)  # explode 1st slice
colors_1 = ['darkkhaki','gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

labels_2 ='Domestic Equities','International \n\n Equities', 'Global Fixed Income', 'Alternatives', 'Cash'
sizes_r2 = [0, 0.263, 0.288, 0.398, 0.050]
explode_2 = (0, 0, 0, 0.1, 0)  # explode 1st slice
colors_2 = ['darkkhaki','gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

fig = plt.figure(figsize=(10,5))
ax = plt.axes()

ax.pie(sizes_r2, explode=explode_2, labels=labels_2, colors=None,
        autopct='%1.1f%%', shadow=True, startangle=140)

ax.axis('equal')
plt.show()
#fig.savefig('Q1Piechart2.eps',format='eps', dpi=1000)

# %%
fig,(axes1,axes2) = plt.figure(figsize=(8,4))

ax = plt.axes()
ax.plot(x,y_2 ,label="Risk Aversion: 2")
ax.plot(x,y_3 ,label="Risk Aversion: 3")
ax.plot(x,y_4 ,label="Risk Aversion: 4")
ax.plot(x,y_5 ,label="Risk Aversion: 5")

ax.set_title("Figure 5. Utility Maximising Indifference Curves for Different Risk Aversion Parameters",fontsize=10)
ax.set_ylabel('Risk Premium',fontsize=12)
ax.set_xlabel(r'${Standard \ Deviation} \ \sigma$',fontsize=12)

plt.legend()

# %%
x = np.arange(0,0.40,0.01)

y_2 = 2*x**2/2 + 0.0275
y_3 = 3*x**2/2 + 0.0275
y_4 = 4*x**2/2 + 0.0275
y_5 = 5*x**2/2 + 0.0275

fig = plt.figure(figsize=(8,4))

ax = plt.axes()
ax.plot(x,y_2 ,label="Risk Aversion: 2")
ax.plot(x,y_3 ,label="Risk Aversion: 3")
ax.plot(x,y_4 ,label="Risk Aversion: 4")
ax.plot(x,y_5 ,label="Risk Aversion: 5")

ax.set_title("Figure 5. Utility Maximising Indifference Curves for Different Risk Aversion Parameters",fontsize=10)
ax.set_ylabel('Risk Premium',fontsize=12)
ax.set_xlabel(r'${Standard \ Deviation} \ \sigma$',fontsize=12)

ax.set_xlim(0.0,0.40)

ax.annotate("Rf",xy=(0,0.0275),xytext=(-0.01,0.0275),fontsize=9,fontweight="bold")

plt.legend()
plt.tight_layout()

# %%
# create an array of numbers from range 0,0.4 in steps of 0.01
x = np.arange(0,0.20,0.01)

# create y values from our x array
yr = 2*x**2/2 + 0.0275

yum_2 = 2*x**2/2 + 0.101


#initiliase fig and ax objects and plot the subplots
fig, (axe1,axe2) = plt.subplots(1, 2, figsize=(9, 4.5))

axe1.plot(x,yrf_2,label="Risk Aversion: 2")
axe1.plot(x,yrf_3,label="Risk Aversion: 3")
axe1.plot(x,yrf_4,label="Risk Aversion: 4")
axe1.plot(x,yrf_5,label="Risk Aversion: 5")

# Various styles and axis settings
axe1.set_title("Figure 5. Risk free rate utility indifference curves for \n various risk aversion parameters",fontsize = 8)
axe1.annotate("Rf",xy=(0,0.0275),xytext=(-0.02,0.0275),fontsize=9,fontweight="bold")

axe1.set_xlim(0,0.20)
axe1.legend()

axe2.plot(x,yum_2,label="Risk Aversion: 2")
axe2.plot(x,yum_3,label="Risk Aversion: 3")
axe2.plot(x,yum_4,label="Risk Aversion: 4")
axe2.plot(x,yum_5,label="Risk Aversion: 5")

axe2.set_title("Figure 5. Utililty maximising indifference curves for \n various risk aversion parameters",fontsize = 8)

axe2.legend()

plt.tight_layout()

# %%
# Data to plot
labels = 'Domestic Equities', 'International Equities', 'Global Fixed Income', 'Alternatives', 'Cash'
sizes_r1 = [0.2, 0.173, 0.159, 0.418, 0.050]
explode_1 = (0, 0, 0, 0.1, 0)  # explode 1st slice
colors_1 = ['darkkhaki','gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

labels_2 ='Domestic Equities','International \n\n Equities', 'Global Fixed Income', 'Alternatives', 'Cash'
sizes_r2 = [0, 0.263, 0.288, 0.398, 0.050]
explode_2 = (0, 0, 0, 0.1, 0)  # explode 1st slice
colors_2 = ['darkkhaki','gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

fig = plt.figure()

ax1 = plt.axes()

ax1.pie(sizes_r1, explode=explode_1, labels=labels, colors=colors_1,
        autopct='%1.1f%%', shadow=True, startangle=140)

ax1.axis('equal')
fig.tight_layout()
plt.show()

# %%
x = np.arange(0,0.25,0.01)

y = 0.0225 + 0.771 * x
y_au = 0.0225 + 0.558 * x
y_n = 0.0225 + 0.733 * x
y_nc = 0.0225 + 0.792 * x

y_e = np.array([0.0856,0.1,0.11,0.12,0.13,0.14])
x_e = np.array([0.0973,0.1041,0.1146,0.1264,0.1392,0.1527])
fig = plt.figure()

ax = plt.axes()
ax.plot(x,y ,label="CAL")
ax.plot(x,y_au,label="100% Australian Equities")
ax.plot(x,y_n,label="1/n Naive")
ax.plot(x,y_nc ,label="No Minimum Investment in Australian Equities")

# expected return markers
ax.plot(0.1289,0.1219,marker='h',color='blue')
ax.plot(0.1289,0.0951,marker='h',color='green')

# x and y labels
ax.set_ylabel(r'$E(r_{p})$',fontsize=12,y=1,rotation='horizontal')
ax.set_xlabel(r'$\sigma_{p}$',fontsize=12,x=1)

# remove ticks
plt.xticks([])
plt.yticks([])

ax.axhline(y=0.1219,xmax=0.50,ls='dashed')
ax.axvline(x=0.1289,ymax=0.50,ls='dashed')

ax.set_xlim(0.0,0.25)

ax.annotate(r"$E$",xy=(0.132,0.085),fontsize=11,fontweight='bold')
ax.annotate(r"$C$",xy=(0.135,0.115),fontsize=11,fontweight='bold')
ax.annotate(r"$r_{f} \ =\ 2.25\%$",xy=(0,0.0225),xytext=(-0.04,0.02225),fontsize=10)
ax.annotate(r"$E(r_{p}) \ = 12.19\%$",xy=(0,0.1219),xytext=(-0.055,0.119),fontsize=10,fontweight='bold')
ax.annotate(r"$\sigma_{p} \ =\ 12.89\%$",xy=(0.1289,0.025),xytext=(0.115,0),fontsize=10)

plt.legend()
plt.tight_layout()
fig.savefig('Q1Linechart.eps',format='eps', dpi=1000,bbox_inches='tight')

# %%
# Data to plot
labels = 'Domestic Equities', 'International Equities', 'Global Fixed Income', 'Alternatives', 'Cash'
sizes_r1 = [0.2, 0.05, 0.45, 0.1, 0.2]
explode_1 = (0, 0, 0.1, 0, 0)  # explode 1st slice
colors_1 = ['darkkhaki','gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

labels_2 ='Domestic \n Equities','International \n Equities', 'Global Fixed Income', 'Single Hedge Fund', 'Cash'
sizes_r2 = [0.2, 0.05, 0.45, 0.1, 0.2]
explode_2 = (0, 0, 0.1, 0, 0)  # explode 1st slice
colors_2 = ['darkkhaki','gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

fig, (ax1,ax2) = plt.subplots(1, 2,figsize=(10,5))

ax1.pie(sizes_r1, explode=explode_1, labels=labels, colors=colors_1,
        autopct='%1.1f%%', shadow=True, startangle=140)

ax2.pie(sizes_r2, explode=explode_2, labels=labels_2, colors=colors_2, 
        autopct='%1.1f%%', shadow=True, startangle=140)

ax1.axis('equal')
fig.tight_layout()
plt.show()
#fig.savefig('Q2Piechart.eps',format='eps', dpi=1000,bbox_inches='tight')

# %%
x = np.arange(0,0.4,0.01)
y_s = 0.0225 + 0.742*x
y_u = 0.0225 + 0.656*x
y_c = 0.0225 + 0.525*x

fig = plt.figure()

ax = plt.axes()
ax.plot(x,y_s ,label="Single Hedge Fund Included")
ax.plot(x,y_u,label="Alternatives, Included")
ax.plot(x,y_c,label="Current Plan")

ax.plot(0.0874,0.0874,marker='h',color='blue')
ax.plot(0.0867,0.0794,marker='h',color='green')
ax.plot(0.0857,0.0675,marker='h',color='red')

ax.set_ylabel(r'$E(r_{p})$',fontsize=12,y=1,rotation='horizontal')
ax.set_xlabel(r'$\sigma_{p}$',fontsize=12,x=1)

plt.xticks([])
plt.yticks([])

ax.axhline(y=0.0874,xmax=0.22,ls='dashed')
ax.axvline(x=0.0867,ymax=0.25,ls='dashed')

ax.set_xlim(0.0,0.40)

ax.annotate(r"$r_{f} \ =\ 2.25\%$",xy=(0,0.022),xytext=(-0.065,0.02),fontsize=10)
ax.annotate(r"$E(r_{p}) \ = 8.74\%$",xy=(0,0.0874),xytext=(-0.08,0.084),fontsize=10,fontweight='bold')
ax.annotate(r"$\sigma_{p} \ \approx 8.67\%$",xy=(0.0867,0.025),xytext=(0.06,-0.012),fontsize=10)

plt.legend()
plt.tight_layout()
#fig.savefig('Q2Linechart.eps',format='eps', dpi=1000,bbox_inches='tight')

# %%
x = np.arange(0,0.60,0.01)
y = np.array([0.0225 + i*0.705 if i < 0.288 else 0.09 + i*0.471 for i in x])

fig = plt.figure()

ax = plt.axes()
ax.plot(x,y,label="Kinked CAL")
ax.plot(0.288,0.225,marker='h',color='red')

ax.set_ylabel(r'$E(r_{p})$',fontsize=12,y=1,rotation='horizontal')
ax.set_xlabel(r'$\sigma_{p}$',fontsize=12,x=1)

ax.annotate(r"$r_{f} \ =\ 2.25\%$",xy=(0,0.0225),xytext=(-0.1,0.0225),fontsize=10)
ax.annotate(r"$E(r_{p}) \ = 22.50\%$",xy=(0,0.225),xytext=(-0.15,0.215),fontsize=10,fontweight='bold')
ax.annotate(r"$\sigma_{p} \ = 28.80\%$",xy=(0.288,0.025),xytext=(0.228,-0.05),fontsize=10)
ax.annotate(r"$S(y \leq 1) = 0.705$",xy=(0.1,0.025),xytext=(0.1,0.05),fontsize=10,fontweight='bold')
ax.annotate(r"$S(y > 1) = 0.471$",xy=(0.3,0.25),xytext=(0.4,0.25),fontsize=10)


ax.set_xlim(0,0.60)
ax.set_ylim(0,0.50)

ax.axhline(y=0.225,xmax=0.80,ls='dashed')
ax.axvline(x=0.288,ymax=0.45,ls='dashed')

ax.axhline(y=0.0225,xmax=0.48,ls='dashed')



plt.xticks([])
plt.yticks([])


plt.legend()
plt.tight_layout()
fig.savefig('KinkedCAL.eps',format='eps', dpi=1000,bbox_inches='tight')

# %%
x = np.arange(0,0.60,0.01)
y = 0.0225 + 0.705*x

y_utility = 0.145 + (2*0.5*x**2)
y_utility2 = 0.175 + (2*0.5*x**2)
y_utility3 = 0.2 + (2*0.5*x**2)

fig = plt.figure()

ax = plt.axes()
ax.plot(x,y,label="Harry's CAL")
ax.plot(x,y_utility,label="U = 0.145 Maximised Utility")
ax.plot(x,y_utility2,label="U = 0.175",ls='dashed')
ax.plot(x,y_utility3,label="U = 0.20",ls='dashed')

ax.plot(0.324,0.25,marker='h',color='blue')
ax.plot(0.288,0.225,marker='h',color='red')

ax.set_ylabel(r'$E(r_{p})$',fontsize=12,y=1,rotation='horizontal')
ax.set_xlabel(r'$\sigma_{p}$',fontsize=12,x=1)

ax.annotate(r"$r_{f} \ =\ 2.25\%$",xy=(0,0.0225),xytext=(-0.13,0.0225),fontsize=10)
ax.annotate(r"$E(r_{p}) \ = 25.00\%$",xy=(0,0.25),xytext=(-0.18,0.25),fontsize=10,fontweight='bold')
ax.annotate(r"$\sigma_{p} \ = 32.40\%$",xy=(0.324,0.025),xytext=(0.24,-0.05),fontsize=10)
ax.annotate(r"$C$",xy=(0.34,0.23),fontsize=11,fontweight='bold')
ax.annotate(r"$P$",xy=(0.30,0.18),fontsize=11,fontweight='bold')

ax.axhline(y=0.25,xmax=0.40,ls='dashed')
ax.axvline(x=0.324,ymax=0.30,ls='dashed')


plt.xticks([])
plt.yticks([])

ax.set_xlim(0,0.8)
ax.set_ylim(-0,0.8)

plt.legend()
plt.tight_layout()
fig.savefig('Q3Utility.eps',format='eps', dpi=1000,bbox_inches='tight')

# %%
# Data to plot
labels = 'Domestic ETF', 'High-Tech \n ETF'
sizes_r1 = [0.274, 0.726]
explode_1 = (0, 0.1)  # explode 1st slice
colors_1 = ['gold', 'yellowgreen', 'lightcoral']

labels_2 ='Domestic ETF', 'High-Tech ETF'
sizes_r2 = [0.083, 0.917]
explode_2 = (0, 0.1)  # explode 1st slice
colors_2 = ['gold', 'yellowgreen', 'lightcoral']

fig, (ax1,ax2) = plt.subplots(1, 2,figsize=(10,5))

ax1.pie(sizes_r1, explode=explode_1, labels=labels, colors=colors_1,
        autopct='%1.1f%%', shadow=True, startangle=140)

ax2.pie(sizes_r2, explode=explode_2, labels=labels_2, colors=colors_2, 
        autopct='%1.1f%%', shadow=True, startangle=140)

ax1.axis('equal')
fig.tight_layout()
plt.show()
fig.savefig('Q3Piechart.eps',format='eps', dpi=1000,bbox_inches='tight')

# %%
x = np.arange(0,0.60,0.01)

y_utility2 = 0.0225 + (2*0.5*x**2)
y_utility3 = 0.0225 + (3*0.5*x**2)
y_utility4 = 0.0225 + (4*0.5*x**2)
y_utility5 = 0.0225 + (5*0.5*x**2)

y_utility0 = 0.0225 + (0*0.5*x**2)
y_utility_1 = 0.0225 + (-1*0.5*x**2)
y_utility_2 = 0.0225 + (-2*0.5*x**2)

fig = plt.figure()

ax = plt.axes()
ax.plot(x,y_utility2,label="A = 2")
ax.plot(x,y_utility3,label="A = 3")
ax.plot(x,y_utility4,label="A = 4")
ax.plot(x,y_utility5,label="A = 5")

ax.plot(x,y_utility0,label="A = 0")
ax.plot(x,y_utility_1,label="A = -1")
ax.plot(x,y_utility_2,label="A = -2")

ax.set_ylabel(r'$E(r_{p})$',fontsize=12,y=1,rotation='horizontal')
ax.set_xlabel(r'$\sigma_{p}$',fontsize=12,x=1)

ax.annotate(r"$r_{f} \ =\ 2.25\%$",xy=(0,0.0225),xytext=(-0.13,0.0225),fontsize=10)

plt.xticks([])
plt.yticks([])

ax.set_xlim(0,0.8)
ax.set_ylim(-0.4,1)

plt.legend()
plt.tight_layout()
fig.savefig('Q3RiskAversion.eps',format='eps', dpi=1000,bbox_inches='tight')

# %%
x = np.arange(0,3,0.01)

y = x*(1+0.01041)**12*5

fig = plt.figure(figsize=(8,4))

ax = plt.axes()
ax.plot(x,y ,label="Risk Aversion: 2")

ax.set_title("Figure 5. Utility Maximising Indifference Curves for Different Risk Aversion Parameters",fontsize=10)
ax.set_ylabel('Risk Premium',fontsize=12)
ax.set_xlabel(r'${Standard \ Deviation} \ \sigma$',fontsize=12)

ax.set_xlim(0.0,0.40)

ax.annotate("Rf",xy=(0,0.0275),xytext=(-0.01,0.0275),fontsize=9,fontweight="bold")

plt.legend()
plt.tight_layout()
